# %% [markdown]
# ### print random number that fall betteen a section of the normal distribution table

# %%
import random
import numpy as np
from numpy.random import randn

# %%
N=10
counter = 0
for i in randn(N):
    if i <= 1 and i >= 0:
        counter +=1
answer = counter/N
print(answer)
# Out:
# 0.3

# %% [markdown]
# We want to be able to input more N

# %%
while True:
    N = int(input('Enter N '))
    if N == 0:
        break

    counter = 0

    for i in randn(N):
        if 0 <= i <=1:
            counter = counter + 1
    answer = counter/N
    print('N =', N)
    print('Estimated value =', answer)
# Out:
# N = 10
# Estimated value = 0.2
# N = 100
# Estimated value = 0.35
# N = 1000
# Estimated value = 0.327
# N = 10000
# Estimated value = 0.3411
# N = 100000
# Estimated value = 0.34253
